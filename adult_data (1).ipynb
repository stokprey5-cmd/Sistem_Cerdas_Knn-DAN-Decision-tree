# %% [markdown]
# # Notebook: Load adult_data.csv

# %%
import pandas as pd

# Untuk spasi atau tab yang tidak teratur
df = pd.read_csv('adult_data.csv', delim_whitespace=True)
df.head()
# Out:
# /tmp/ipython-input-361525530.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('adult_data.csv', delim_whitespace=True)
#                     {
# cells:              [
# {                 NaN
# cell_type:  markdown,
# id:         ca96a71e,
# metadata:         {},

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
