# %% [markdown]
# # Analisis Data decisiontree_1
#
# Notebook ini dibuat otomatis dari file `decisiontree_1.csv`.
#
# Isi notebook:
# 1. Import library
# 2. Load data dari CSV
# 3. Menampilkan beberapa baris pertama data

# %%
import pandas as pd

# Tampilkan versi pandas
pd.__version__

# %%
# Ganti path sesuai lokasi file Anda
df = pd.read_csv("decisiontree_1.csv")
df.head()

# %%
# Informasi struktur data
df.info()

# %%
# Statistik deskriptif
df.describe(include='all')
